# %% [markdown]
# ### Create readme.txt file

# %%
import os
import sys
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from scipy.io import savemat

sys.path.append(os.path.abspath('../helper'))
import config
import utils
import loader
import plotfig
import utils_transfer

# %%
source_models_dir  = "../model/static/CNN/BS16/3500_3516/ver27_"
target_data_dir    = "../../CDL Customization/Data/ver39_"

# Min-max Scaler to [-1 1] range
norm_approach = 'minmax'
lower_range = -1
CNN_DropOut = 0.2
CNN_activation = 'Tanh'
train_rate = 0.3 # train_rate/(1-train_rate) for training/validating at transferring

# create readme.txt file
content = f"""Generated by file 'transfer/transfer_v7.ipynb'.
Source models were loaded in {source_models_dir},
Target training data are loaded in {target_data_dir}
1000 samples in target dataset (map-based dataset), {str(train_rate)} for training, {str(1-train_rate)} for validating and evaluating
Finetune models don't have padding at 2 last layers 
"""

idx_save_path = loader.find_incremental_filename('transferd_model/static/CNN', 'ver', '_', '')
transferd_save_path = f"transferd_model/static/CNN/ver{idx_save_path}_"

os.makedirs(os.path.dirname(f'{transferd_save_path}/readme.txt'), exist_ok=True)

# Write content to readme.txt
with open(transferd_save_path + '/readme.txt', "w") as file:
    file.write(content)

# %%
# Straightly applying trained model to target data

# %%
# Configuration
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

BATCH_SIZE = 32 #64  # Batch size
NUM_EPOCHS = 50 # 20
learning_rate = 1e-5 # 1e-5
SNR = np.arange(-25, -4, 5) # 0:5:30 dB

nmse_LS_LI_val   = []
nmse_LS_NN_val   = []
nmse_LI_NN_val   = []

for snr in SNR:
    print(f" SNR: {snr}/{SNR[-1]}")
    # load target dataset
    [trainLabels, valLabels], [H_equal_train, H_linear_train, H_practical_train], [H_equal_val, H_linear_val, H_practical_val] = loader.load_map_data(target_data_dir, device, snr, train_rate=train_rate)
            
    # training at target set
    for model_name in ['LS_CNN', 'LS_LI_CNN']:
        print(f'{model_name} model')
        
        if model_name == 'LS_CNN':
            train_loader, trainLabel_min, trainLabel_max = loader.genLoader(H_equal_train, trainLabels, BATCH_SIZE, device, 'train', True, norm_approach, lower_range=lower_range)
            val_loader,     valLabel_min,   valLabel_max = loader.genLoader(H_equal_val,     valLabels, BATCH_SIZE, device, 'valid', False, norm_approach, lower_range=lower_range)
            # no shuffle in validation so valLabel_min and valLable_max remain the min and max arrays
                                                                                        # of valLabels
            # train_loader, val_loader are already normalized by their own min, max
            # scale to range [0 1] or [-1 1]
            
            # source model
            model_source = utils.CNN_Est(dropOut=0, act =CNN_activation).to(device)
        
            
        elif model_name == 'LS_LI_CNN':
            train_loader, trainLabel_min, trainLabel_max = loader.genLoader(H_linear_train, trainLabels, BATCH_SIZE, device, 'train', True, norm_approach, lower_range=lower_range)
            val_loader,     valLabel_min,   valLabel_max = loader.genLoader(H_linear_val,     valLabels, BATCH_SIZE, device, 'valid', False, norm_approach, lower_range=lower_range)
            # no shuffle in validation so valLabel_min and valLable_max remain the min and max arrays
                                                                                        # of valLabels
            # train_loader, val_loader are already normalized by their own min, max
            # scale to range [0 1] or [-1 1]
            
            # source model
            model_source = utils.CNN_Est(dropOut=CNN_DropOut, act =CNN_activation).to(device)
        
        
        checkpoint = torch.load(os.path.join(source_models_dir, f'{snr}dB', f'CNN_1_{model_name}_model.pth'))
        model_source.load_state_dict(checkpoint['model_state_dict'])
        
        model_fineTune = utils_transfer.FineTuneModel2(model_source).to(device)
        optimizer = torch.optim.Adam(model_fineTune.parameters(), lr=learning_rate)
        criterion = nn.MSELoss()
        
        train_loss =[]
        val_loss = []
        H_NN_val = torch.empty_like(valLabels) # [nVal, 2, 612, 14]
        min_H_true = []
        max_H_true = []
        num_epochs = NUM_EPOCHS
        for epoch in range(num_epochs):
            model_fineTune.train()
            running_loss = 0.0
            if (epoch == num_epochs-1):
                i = 0
            for inputs, targets, targets_min, targets_max in train_loader:
                optimizer.zero_grad()
                outputs = model_fineTune(inputs)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                
            avg_train_loss = running_loss / len(train_loader)
            train_loss.append(avg_train_loss)
            print(f"SNR: {snr}/{SNR[-1]}, {model_name}, Epoch {epoch+1}/{num_epochs}, Loss: {avg_train_loss} ")
            
            # Validation 
            model_fineTune.eval()
            running_val_loss = 0.0
            with torch.no_grad():
                for val_inputs, val_targets, val_targetsMin, val_targetsMax in val_loader:
                    val_inputs_real = val_inputs[:,0,:,:].unsqueeze(1)
                    val_inputs_imag = val_inputs[:,1,:,:].unsqueeze(1)
                    val_targets_real = val_targets[:,0,:,:].unsqueeze(1)
                    val_targets_imag = val_targets[:,1,:,:].unsqueeze(1)
                    
                    val_outputs_real = model_fineTune(val_inputs_real)
                    val_loss_real = criterion(val_outputs_real, val_targets_real)
                    running_val_loss += val_loss_real.item()
                    
                    val_outputs_imag = model_fineTune(val_inputs_imag)
                    val_loss_imag = criterion(val_outputs_imag, val_targets_imag)
                    running_val_loss += val_loss_imag.item()
                    
                    if (epoch == num_epochs-1): # the results after the last training epoch
                        H_NN_val[i:i+val_outputs_real.size(0),0,:,:].unsqueeze(1).copy_(val_outputs_real)
                        H_NN_val[i:i+val_outputs_imag.size(0),1,:,:].unsqueeze(1).copy_(val_outputs_imag)
                        
                        i = i+val_outputs_imag.size(0)       
                        
                    
            avg_val_loss = running_val_loss / (len(val_loader)*2)
            val_loss.append(avg_val_loss)    
                    
            print(f"SNR: {snr}/{SNR[-1]}, {model_name}, Val Loss: {avg_val_loss}")
        # end loop epochs
        
        train_save_path = f'{transferd_save_path}/{snr}dB/train'
        os.makedirs(train_save_path, exist_ok=True)
        
        savemat(f'{train_save_path}/{model_name}_loss.mat', {f'val_loss': val_loss, 
                                                            f'train_loss': train_loss})
        
        plotfig.figLoss(train_loss, val_loss, 1, train_save_path, f'_{model_name}_Loss.png')
        
        torch.save({
            'model_state_dict': model_fineTune.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()
        }, f'{transferd_save_path}/{snr}dB/{model_name}_model.pth')
        
        
        # Denormalize True Channel
        H_val_true = valLabels.cpu()
        # convert to complex matrices
        H_val_true_complex = torch.complex(H_val_true[:,0,:,:], H_val_true[:,1,:,:])
        # variables['H_val_true'] = H_val_true # (nVal, 2, 612, 14)
        plotfig.figTrueChan(H_val_true[-1,0,:,:], 'True Channel', 1, train_save_path, '_trueChannel.png')
                            # train_save_path = f'transferd_model/static/CNN/ver{idx_save_path}_/{snr}dB/train'

        
        # CNN Estimated Channel                                                               
        H_val_NN_denormd = utils.deNorm(H_NN_val, valLabel_min, valLabel_max, norm_approach, lower_range=lower_range)
                            #     H_NN_val == [nVal, 2, 612, 14] 
                            # valLabel_min == [nVal,1]
        H_val_NN_denormd = H_val_NN_denormd.cpu()
        
        # NMSE of LS (+ LI) + CNN
        H_val_NN_complex = torch.complex(H_val_NN_denormd[:,0,:,:], H_val_NN_denormd[:,1,:,:])# Calculate the NMSE
        nmse_NN = utils.calNMSE(H_val_NN_complex, H_val_true_complex)
            
        if model_name == 'LS_CNN':
            nmse_LS_NN_val.append(nmse_NN.cpu().mean())
            print(f"LS+CNN NMSE: {nmse_NN.cpu().mean()}")
            
            plotfig.figPredChan(H_val_NN_denormd[-1,0,:,:], 'LS+CNN Estimated Channel',
                                    nmse_NN[-1], 1, train_save_path, '_LS_CNN_estimatedChan.png')
                                # train_save_path = f'transferd_model/static/CNN/ver{idx_save_path}_/{snr}dB/train'
        
            # NMSE of Linear Interpolation   # just need to calculate this 1 time  --> calculate at case model_name == 'LS_CNN'
            H_val_linInterp = H_linear_val.cpu()
            # convert to complex matrices
            H_val_linInterp_complex = torch.complex(H_val_linInterp[:,0,:,:], H_val_linInterp[:,1,:,:]) # [?, 612, 14]
            nmse_LI = utils.calNMSE(H_val_linInterp_complex, H_val_true_complex)
            
            nmse_LS_LI_val.append(nmse_LI.cpu().mean())
            print(f"LS+LI NMSE: {nmse_LI.cpu().mean()}")
            
            plotfig.figPredChan(H_val_linInterp[-1,0,:,:], 'LS + Interpolate Estimated Channel',
                                    nmse_LI[-1], 1, train_save_path, '_LS_LI_estimatedChan.png')
                            # train_save_path = f'transferd_model/static/CNN/ver{idx_save_path}_/{snr}dB/train'
                            
        elif model_name == 'LS_LI_CNN':
            nmse_LI_NN_val.append(nmse_NN.cpu().mean())
            print(f"LS+CNN NMSE: {nmse_NN.cpu().mean()}")
            
            plotfig.figPredChan(H_val_NN_denormd[-1,0,:,:], 'LS+LI+CNN Estimated Channel',
                                    nmse_NN[-1], 1, train_save_path, '_LS_LI_CNN_estimatedChan.png')
                                # train_save_path = f'transferd_model/static/CNN/ver{idx_save_path}_/{snr}dB/train'
    
    # end model_phase ['LS_CNN', 'LS_LI_CNN']
# end loop SNR
# Out:
#  SNR: -25/-5
# /home/thien/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# LS_CNN model
# SNR: -25/-5, LS_CNN, Epoch 1/50, Loss: 0.40897025995784336
# SNR: -25/-5, LS_CNN, Val Loss: 0.4004656406848327
# SNR: -25/-5, LS_CNN, Epoch 2/50, Loss: 0.40700217750337386
# SNR: -25/-5, LS_CNN, Val Loss: 0.39869015696256055
# SNR: -25/-5, LS_CNN, Epoch 3/50, Loss: 0.40540193683571285
# SNR: -25/-5, LS_CNN, Val Loss: 0.397186072624248
# SNR: -25/-5, LS_CNN, Epoch 4/50, Loss: 0.4040271010663774
# SNR: -25/-5, LS_CNN, Val Loss: 0.39586332181225653
# SNR: -25/-5, LS_CNN, Epoch 5/50, Loss: 0.40281935698456234
# SNR: -25/-5, LS_CNN, Val Loss: 0.39466725030670996
# SNR: -25/-5, LS_CNN, Epoch 6/50, Loss: 0.40173744327492183
# SNR: -25/-5, LS_CNN, Val Loss: 0.3936163491528967
# SNR: -25/-5, LS_CNN, Epoch 7/50, Loss: 0.40076963272359634
# SNR: -25/-5, LS_CNN, Val Loss: 0.39256481048853503
# SNR: -25/-5, LS_CNN, Epoch 8/50, Loss: 0.39990880919827354
# SNR: -25/-5, LS_CNN, Val Loss: 0.3783950766791468
# SNR: -25/-5, LS_CNN, Epoch 29/50, Loss: 0.3858517524268892
# SNR: -25/-5, LS_CNN, Val Loss: 0.3777404874563217
# SNR: -25/-5, LS_CNN, Epoch 30/50, Loss: 0.3853118187851376
# SNR: -25/-5, LS_CNN, Val Loss: 0.37731119795985846
# SNR: -25/-5, LS_CNN, Epoch 31/50, Loss: 0.38488006922933793
# SNR: -25/-5, LS_CNN, Val Loss: 0.3769137898217077
# SNR: -25/-5, LS_CNN, Epoch 32/50, Loss: 0.3842422482040193
# SNR: -25/-5, LS_CNN, Val Loss: 0.3763804364463557
# SNR: -25/-5, LS_CNN, Epoch 33/50, Loss: 0.383934380279647
# SNR: -25/-5, LS_CNN, Val Loss: 0.37600616074126697
# SNR: -25/-5, LS_CNN, Epoch 34/50, Loss: 0.38336580495039624
# SNR: -25/-5, LS_CNN, Val Loss: 0.3755039903132812
# SNR: -25/-5, LS_CNN, Epoch 35/50, Loss: 0.38313033680121106
# SNR: -25/-5, LS_CNN, Val Loss: 0.37511868062226666
# SNR: -25/-5, LS_CNN, Epoch 36/50, Loss: 0.38268380363782245
# SNR: -25/-5, LS_CNN, Val Loss: 0.3748449417559997
# SNR: -25/-5, LS_CNN, Epoch 37/50, Loss: 0.3824278281794654
# SNR: -25/-5, LS_CNN, Val Loss: 0.3744588520215905
# SNR: -25/-5, LS_CNN, Epoch 38/50, Loss: 0.38191214203834534
# SNR: -25/-5, LS_CNN, Val Loss: 0.3741311320792074
# SNR: -25/-5, LS_CNN, Epoch 39/50, Loss: 0.3813847104708354
# SNR: -25/-5, LS_CNN, Val Loss: 0.3737866839636927
# SNR: -25/-5, LS_CNN, Epoch 40/50, Loss: 0.3815011862251494
# SNR: -25/-5, LS_CNN, Val Loss: 0.37358018108036206
# SNR: -25/-5, LS_CNN, Epoch 41/50, Loss: 0.3807337350315518
# SNR: -25/-5, LS_CNN, Val Loss: 0.37319454485955444
# SNR: -25/-5, LS_CNN, Epoch 42/50, Loss: 0.38068273497952354
# SNR: -25/-5, LS_CNN, Val Loss: 0.37296573040278064
# SNR: -25/-5, LS_CNN, Epoch 43/50, Loss: 0.3802030798461702
# SNR: -25/-5, LS_CNN, Val Loss: 0.3726948402498079
# SNR: -25/-5, LS_CNN, Epoch 44/50, Loss: 0.380213651392195
# SNR: -25/-5, LS_CNN, Val Loss: 0.37250760651153064
# SNR: -25/-5, LS_CNN, Epoch 45/50, Loss: 0.3801164709859424
# SNR: -25/-5, LS_CNN, Val Loss: 0.3722890576590662
# SNR: -25/-5, LS_CNN, Epoch 46/50, Loss: 0.37971410155296326
# SNR: -25/-5, LS_CNN, Val Loss: 0.3721086965954822
# SNR: -25/-5, LS_CNN, Epoch 47/50, Loss: 0.3794145319196913
# SNR: -25/-5, LS_CNN, Val Loss: 0.3720047694185506
# SNR: -25/-5, LS_CNN, Epoch 48/50, Loss: 0.3793688830402162
# SNR: -20/-5, LS_LI_CNN, Val Loss: 0.3875975647698278
# SNR: -20/-5, LS_LI_CNN, Epoch 48/50, Loss: 0.38428721328576404
# SNR: -20/-5, LS_LI_CNN, Val Loss: 0.3875758090744848
# SNR: -20/-5, LS_LI_CNN, Epoch 49/50, Loss: 0.38507644169860417
# SNR: -20/-5, LS_LI_CNN, Val Loss: 0.38755494291367737
# SNR: -20/-5, LS_LI_CNN, Epoch 50/50, Loss: 0.38469699521859485
# SNR: -20/-5, LS_LI_CNN, Val Loss: 0.3876238076583199
# LS+CNN NMSE: 0.1082896962761879
#  SNR: -15/-5
# LS_CNN model
# SNR: -15/-5, LS_CNN, Epoch 1/50, Loss: 0.3955157779985004
# SNR: -15/-5, LS_CNN, Val Loss: 0.40183494013288745
# SNR: -15/-5, LS_CNN, Epoch 2/50, Loss: 0.3894392533434762
# SNR: -15/-5, LS_CNN, Val Loss: 0.39600568750630255
# SNR: -15/-5, LS_CNN, Epoch 3/50, Loss: 0.3836293700668547
# SNR: -15/-5, LS_CNN, Val Loss: 0.3904080228961032
# SNR: -15/-5, LS_CNN, Epoch 4/50, Loss: 0.3785365770260493
# SNR: -15/-5, LS_CNN, Val Loss: 0.38520522026912024
# SNR: -15/-5, LS_CNN, Epoch 5/50, Loss: 0.37385542690753937
# SNR: -15/-5, LS_CNN, Val Loss: 0.38055696889110235
# SNR: -15/-5, LS_CNN, Epoch 6/50, Loss: 0.3696554634306166
# SNR: -15/-5, LS_CNN, Val Loss: 0.3765593015629312
# SNR: -15/-5, LS_CNN, Epoch 7/50, Loss: 0.3658653365241157
# SNR: -15/-5, LS_CNN, Val Loss: 0.37317829870659375
# SNR: -15/-5, LS_CNN, Epoch 8/50, Loss: 0.36260271403524613
# SNR: -15/-5, LS_CNN, Val Loss: 0.3695613392021345
# SNR: -15/-5, LS_CNN, Epoch 9/50, Loss: 0.36029228071371716
# SNR: -15/-5, LS_CNN, Val Loss: 0.367263934534529
# SNR: -15/-5, LS_CNN, Epoch 10/50, Loss: 0.3578205621904797
# SNR: -15/-5, LS_CNN, Val Loss: 0.36542617885962775
# SNR: -15/-5, LS_CNN, Epoch 11/50, Loss: 0.3564961188369327
# SNR: -15/-5, LS_CNN, Val Loss: 0.36376595626706665
# SNR: -15/-5, LS_CNN, Epoch 12/50, Loss: 0.35478219555483925
# SNR: -15/-5, LS_CNN, Val Loss: 0.3624829507392386
# SNR: -15/-5, LS_CNN, Epoch 13/50, Loss: 0.353155051668485
# SNR: -15/-5, LS_CNN, Val Loss: 0.3611000581927922
# SNR: -15/-5, LS_CNN, Epoch 14/50, Loss: 0.3521584024031957
# SNR: -15/-5, LS_CNN, Val Loss: 0.35970841153808264
# SNR: -15/-5, LS_CNN, Epoch 15/50, Loss: 0.351110029551718
# SNR: -15/-5, LS_CNN, Val Loss: 0.3585230610940767
# SNR: -15/-5, LS_CNN, Epoch 16/50, Loss: 0.3499679250849618
# SNR: -15/-5, LS_CNN, Val Loss: 0.35722721206105273
# SNR: -15/-5, LS_CNN, Epoch 17/50, Loss: 0.34896212153964573
# SNR: -15/-5, LS_CNN, Val Loss: 0.35640288565469824
# SNR: -15/-5, LS_CNN, Epoch 18/50, Loss: 0.34780484106805587
# SNR: -15/-5, LS_CNN, Val Loss: 0.3551353650248569
# SNR: -15/-5, LS_CNN, Epoch 19/50, Loss: 0.3466804093784756
# SNR: -15/-5, LS_CNN, Val Loss: 0.3541350163843321
# SNR: -15/-5, LS_CNN, Epoch 20/50, Loss: 0.3453126715289222
# SNR: -15/-5, LS_CNN, Val Loss: 0.3530924248954524
# SNR: -15/-5, LS_CNN, Epoch 21/50, Loss: 0.3443436010016335
# SNR: -15/-5, LS_CNN, Val Loss: 0.3521147908075996
# SNR: -15/-5, LS_CNN, Epoch 22/50, Loss: 0.34315840403238934
# SNR: -15/-5, LS_CNN, Val Loss: 0.35097825138465216
# SNR: -15/-5, LS_CNN, Epoch 23/50, Loss: 0.34234754741191864
# SNR: -15/-5, LS_CNN, Val Loss: 0.3497873946376469
# SNR: -15/-5, LS_CNN, Epoch 24/50, Loss: 0.34096246626642013
# SNR: -15/-5, LS_CNN, Val Loss: 0.3487008712861849
# SNR: -15/-5, LS_CNN, Epoch 25/50, Loss: 0.3395673632621765
# SNR: -15/-5, LS_CNN, Val Loss: 0.3479234550310218
# SNR: -15/-5, LS_CNN, Epoch 26/50, Loss: 0.338870119717386
# SNR: -15/-5, LS_CNN, Val Loss: 0.3463416857563931
# SNR: -15/-5, LS_CNN, Epoch 27/50, Loss: 0.33771715727117324
# SNR: -15/-5, LS_CNN, Val Loss: 0.34514915360056836
# SNR: -15/-5, LS_CNN, Epoch 28/50, Loss: 0.3363594992293252
# SNR: -15/-5, LS_CNN, Val Loss: 0.34423890385938727
# SNR: -15/-5, LS_CNN, Epoch 29/50, Loss: 0.33475786613093483
# SNR: -15/-5, LS_CNN, Val Loss: 0.34336930578169617
# SNR: -15/-5, LS_CNN, Epoch 30/50, Loss: 0.334421048561732
# SNR: -15/-5, LS_CNN, Val Loss: 0.34177250900994177
# SNR: -15/-5, LS_CNN, Epoch 31/50, Loss: 0.3326077808936437
# SNR: -15/-5, LS_CNN, Val Loss: 0.3404690383569054
# SNR: -15/-5, LS_CNN, Epoch 32/50, Loss: 0.3308740705251694
# SNR: -15/-5, LS_CNN, Val Loss: 0.3395367601643438
# SNR: -15/-5, LS_CNN, Epoch 33/50, Loss: 0.32938679224914974
# SNR: -15/-5, LS_CNN, Val Loss: 0.3384152631396833
# SNR: -15/-5, LS_CNN, Epoch 34/50, Loss: 0.32808250685532886
# SNR: -15/-5, LS_CNN, Val Loss: 0.33677196502685547
# SNR: -15/-5, LS_CNN, Epoch 35/50, Loss: 0.3274003267288208
# SNR: -15/-5, LS_CNN, Val Loss: 0.33560204894646356
# SNR: -15/-5, LS_CNN, Epoch 36/50, Loss: 0.32617242137591046
# SNR: -15/-5, LS_CNN, Val Loss: 0.3344056133342826
# SNR: -15/-5, LS_CNN, Epoch 37/50, Loss: 0.32421501146422493
# SNR: -15/-5, LS_CNN, Val Loss: 0.3332969429700271
# SNR: -15/-5, LS_CNN, Epoch 38/50, Loss: 0.3249945375654433
# SNR: -15/-5, LS_CNN, Val Loss: 0.3319133364635965
# SNR: -15/-5, LS_CNN, Epoch 39/50, Loss: 0.32164627810319263
# SNR: -15/-5, LS_CNN, Val Loss: 0.3309055411297342
# SNR: -15/-5, LS_CNN, Epoch 40/50, Loss: 0.32115259601010215
# SNR: -15/-5, LS_CNN, Val Loss: 0.32936750935471576
# SNR: -15/-5, LS_CNN, Epoch 41/50, Loss: 0.31919900245136684
# SNR: -15/-5, LS_CNN, Val Loss: 0.32818443814049597
# SNR: -15/-5, LS_CNN, Epoch 42/50, Loss: 0.31788108580642277
# SNR: -15/-5, LS_CNN, Val Loss: 0.32708143151324726
# SNR: -15/-5, LS_CNN, Epoch 43/50, Loss: 0.31582962307665086
# SNR: -15/-5, LS_CNN, Val Loss: 0.3259192711633185
# SNR: -15/-5, LS_CNN, Epoch 44/50, Loss: 0.3150290052096049
# SNR: -15/-5, LS_CNN, Val Loss: 0.3244121858607168
# SNR: -15/-5, LS_CNN, Epoch 45/50, Loss: 0.3151513901021745
# SNR: -15/-5, LS_CNN, Val Loss: 0.3233589815056842
# SNR: -15/-5, LS_CNN, Epoch 46/50, Loss: 0.31333767539925045
# SNR: -15/-5, LS_CNN, Val Loss: 0.32246858464634937
# SNR: -15/-5, LS_CNN, Epoch 47/50, Loss: 0.31067470875051284
# SNR: -15/-5, LS_CNN, Val Loss: 0.32102995009525964
# SNR: -15/-5, LS_CNN, Epoch 48/50, Loss: 0.31252144111527336
# SNR: -15/-5, LS_CNN, Val Loss: 0.3199725805417351
# SNR: -15/-5, LS_CNN, Epoch 49/50, Loss: 0.313345053129726
# SNR: -15/-5, LS_CNN, Val Loss: 0.3192427255537199
# SNR: -15/-5, LS_CNN, Epoch 50/50, Loss: 0.30904751519362134
# SNR: -15/-5, LS_CNN, Val Loss: 0.3184597952210385
# LS+CNN NMSE: 0.0743146538734436
# LS+LI NMSE: 2.5915701389312744
# LS_LI_CNN model
# SNR: -15/-5, LS_LI_CNN, Epoch 1/50, Loss: 0.39964236484633553
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.4082256834144178
# SNR: -15/-5, LS_LI_CNN, Epoch 2/50, Loss: 0.3969453705681695
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.4054925351039223
# SNR: -15/-5, LS_LI_CNN, Epoch 3/50, Loss: 0.3944816357559628
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.4028807029775951
# SNR: -15/-5, LS_LI_CNN, Epoch 4/50, Loss: 0.39222904708650375
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.40060761959656427
# SNR: -15/-5, LS_LI_CNN, Epoch 5/50, Loss: 0.3902972489595413
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.39868448350740515
# SNR: -15/-5, LS_LI_CNN, Epoch 6/50, Loss: 0.388287956515948
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.39644586651221564
# SNR: -15/-5, LS_LI_CNN, Epoch 7/50, Loss: 0.38661397165722317
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3946856668461924
# SNR: -15/-5, LS_LI_CNN, Epoch 8/50, Loss: 0.38553376330269706
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.39281760804031207
# SNR: -15/-5, LS_LI_CNN, Epoch 9/50, Loss: 0.384387269616127
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38209668255370594
# SNR: -15/-5, LS_LI_CNN, Epoch 40/50, Loss: 0.37426788442664677
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38176218711811566
# SNR: -15/-5, LS_LI_CNN, Epoch 41/50, Loss: 0.3753824316793018
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38145140331724414
# SNR: -15/-5, LS_LI_CNN, Epoch 42/50, Loss: 0.3736473669608434
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3814302637525227
# SNR: -15/-5, LS_LI_CNN, Epoch 43/50, Loss: 0.37438704901271397
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38120697568292206
# SNR: -15/-5, LS_LI_CNN, Epoch 44/50, Loss: 0.37363406519095105
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38090017891448474
# SNR: -15/-5, LS_LI_CNN, Epoch 45/50, Loss: 0.37360917859607273
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38137388682883716
# SNR: -15/-5, LS_LI_CNN, Epoch 46/50, Loss: 0.3743388139539295
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3808271191690279
# SNR: -15/-5, LS_LI_CNN, Epoch 47/50, Loss: 0.3740144587225384
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3809587158586668
# SNR: -15/-5, LS_LI_CNN, Epoch 48/50, Loss: 0.3733289490143458
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3806661088829455
# SNR: -15/-5, LS_LI_CNN, Epoch 49/50, Loss: 0.3744882692893346
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.38042742985746136
# SNR: -15/-5, LS_LI_CNN, Epoch 50/50, Loss: 0.37407606343428296
# SNR: -15/-5, LS_LI_CNN, Val Loss: 0.3804669678211212
# LS+CNN NMSE: 0.10392364859580994
# /home/thien/Hprediction/one_shot_Hest_cleanver/Torch_code/helper/plotfig.py:35: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 5))
#  SNR: -10/-5
# LS_CNN model
# SNR: -10/-5, LS_CNN, Epoch 1/50, Loss: 0.3972748534546958
# SNR: -10/-5, LS_CNN, Val Loss: 0.38513028427310614
# SNR: -10/-5, LS_CNN, Epoch 2/50, Loss: 0.3943942603137758
# SNR: -10/-5, LS_CNN, Val Loss: 0.3824833190959433
# SNR: -10/-5, LS_CNN, Epoch 3/50, Loss: 0.39145342177814907
# SNR: -10/-5, LS_CNN, Val Loss: 0.37967229731704877
# SNR: -10/-5, LS_CNN, Epoch 4/50, Loss: 0.3891330245468352
# SNR: -10/-5, LS_CNN, Val Loss: 0.37710059596144635
# SNR: -10/-5, LS_CNN, Epoch 5/50, Loss: 0.38637743062443203
# SNR: -10/-5, LS_CNN, Val Loss: 0.3743769597748052
# SNR: -10/-5, LS_CNN, Epoch 6/50, Loss: 0.3836235950390498
# SNR: -10/-5, LS_CNN, Val Loss: 0.3715006022349648
# SNR: -10/-5, LS_CNN, Epoch 7/50, Loss: 0.38116762042045593
# SNR: -10/-5, LS_CNN, Val Loss: 0.36881825457448547
# SNR: -10/-5, LS_CNN, Epoch 8/50, Loss: 0.37859619160493213
# SNR: -10/-5, LS_CNN, Val Loss: 0.36637411493322125
# SNR: -10/-5, LS_CNN, Epoch 9/50, Loss: 0.3761848790778054
# SNR: -10/-5, LS_CNN, Val Loss: 0.3635728527670321
# SNR: -10/-5, LS_CNN, Epoch 10/50, Loss: 0.3741205450561311
# SNR: -10/-5, LS_CNN, Val Loss: 0.360873479558074
# SNR: -10/-5, LS_CNN, Epoch 11/50, Loss: 0.3717772050036324
# SNR: -10/-5, LS_CNN, Epoch 32/50, Loss: 0.32337703473038143
# SNR: -10/-5, LS_CNN, Val Loss: 0.3054439010827438
# SNR: -10/-5, LS_CNN, Epoch 33/50, Loss: 0.31948697732554543
# SNR: -10/-5, LS_CNN, Val Loss: 0.30362274724504223
# SNR: -10/-5, LS_CNN, Epoch 34/50, Loss: 0.31453465753131443
# SNR: -10/-5, LS_CNN, Val Loss: 0.30056885986224463
# SNR: -10/-5, LS_CNN, Epoch 35/50, Loss: 0.3135906904935837
# SNR: -10/-5, LS_CNN, Val Loss: 0.29772548442301544
# SNR: -10/-5, LS_CNN, Epoch 36/50, Loss: 0.3097983996073405
# SNR: -10/-5, LS_CNN, Val Loss: 0.295755904653798
# SNR: -10/-5, LS_CNN, Epoch 37/50, Loss: 0.3081357495652305
# SNR: -10/-5, LS_CNN, Val Loss: 0.29352187721625617
# SNR: -10/-5, LS_CNN, Epoch 38/50, Loss: 0.3061784952878952
# SNR: -10/-5, LS_CNN, Val Loss: 0.29066451153029566
# SNR: -10/-5, LS_CNN, Epoch 39/50, Loss: 0.30162109434604645
# SNR: -10/-5, LS_CNN, Val Loss: 0.28751398169476056
# SNR: -10/-5, LS_CNN, Epoch 40/50, Loss: 0.2992250406079822
# SNR: -10/-5, LS_CNN, Val Loss: 0.2852247784967008
# SNR: -10/-5, LS_CNN, Epoch 41/50, Loss: 0.2991231464677387
# SNR: -10/-5, LS_CNN, Val Loss: 0.2840415576229925
# SNR: -10/-5, LS_CNN, Epoch 42/50, Loss: 0.2982964697811339
# SNR: -10/-5, LS_CNN, Val Loss: 0.28116508281749225
# SNR: -10/-5, LS_CNN, Epoch 43/50, Loss: 0.2997756004333496
# SNR: -10/-5, LS_CNN, Val Loss: 0.27832346571528394
# SNR: -10/-5, LS_CNN, Epoch 44/50, Loss: 0.2922133066587978
# SNR: -10/-5, LS_CNN, Val Loss: 0.2770623065855192
# SNR: -10/-5, LS_CNN, Epoch 45/50, Loss: 0.29711167017618817
# SNR: -10/-5, LS_CNN, Val Loss: 0.2741067458106124
# SNR: -10/-5, LS_CNN, Epoch 46/50, Loss: 0.2882288189397918
# SNR: -10/-5, LS_CNN, Val Loss: 0.2722039083423822
# SNR: -10/-5, LS_CNN, Epoch 47/50, Loss: 0.28764622327354217
# SNR: -10/-5, LS_CNN, Val Loss: 0.26988569355529285
# SNR: -10/-5, LS_CNN, Epoch 48/50, Loss: 0.2849043036500613
# SNR: -10/-5, LS_CNN, Val Loss: 0.26844171985335974
# SNR: -10/-5, LS_CNN, Epoch 49/50, Loss: 0.2864420869284206
# SNR: -10/-5, LS_CNN, Val Loss: 0.26761705914269324
# SNR: -10/-5, LS_CNN, Epoch 50/50, Loss: 0.28544171568420196
# SNR: -10/-5, LS_CNN, Val Loss: 0.2650962131826774
# LS+CNN NMSE: 0.04999205097556114
# LS+LI NMSE: 0.8182691335678101
# LS_LI_CNN model
# SNR: -10/-5, LS_LI_CNN, Epoch 1/50, Loss: 0.3951544430520799
# SNR: -10/-5, LS_LI_CNN, Val Loss: 0
# SNR: -5/-5, LS_CNN, Epoch 6/50, Loss: 0.4098347607586119
# SNR: -5/-5, LS_CNN, Val Loss: 0.4009663449681323
# SNR: -5/-5, LS_CNN, Epoch 7/50, Loss: 0.40775453713205123
# SNR: -5/-5, LS_CNN, Val Loss: 0.3988731140675752
# SNR: -5/-5, LS_CNN, Epoch 8/50, Loss: 0.40611857175827026
# SNR: -5/-5, LS_CNN, Val Loss: 0.3963850470988647
# SNR: -5/-5, LS_CNN, Epoch 9/50, Loss: 0.4041009561883079
# SNR: -5/-5, LS_CNN, Val Loss: 0.3951600148625996
# SNR: -5/-5, LS_CNN, Epoch 10/50, Loss: 0.40210238099098206
# SNR: -5/-5, LS_CNN, Val Loss: 0.39273795096770575
# SNR: -5/-5, LS_CNN, Epoch 11/50, Loss: 0.39940713511572945
# SNR: -5/-5, LS_CNN, Val Loss: 0.39061620637126593
# SNR: -5/-5, LS_CNN, Epoch 12/50, Loss: 0.39822208053535885
# SNR: -5/-5, LS_CNN, Val Loss: 0.3878781899161961
# SNR: -5/-5, LS_CNN, Epoch 13/50, Loss: 0.395512118935585
# SNR: -5/-5, LS_CNN, Val Loss: 0.38605962628903595
# SNR: -5/-5, LS_CNN, Epoch 14/50, Loss: 0.39373478790124256
# SNR: -5/-5, LS_CNN, Val Loss: 0.3842844878849776
# SNR: -5/-5, LS_CNN, Epoch 15/50, Loss: 0.3913200514184104
# SNR: -5/-5, LS_CNN, Val Loss: 0.3825296150601428
# SNR: -5/-5, LS_CNN, Epoch 16/50, Loss: 0.3887743618753221
# SNR: -5/-5, LS_CNN, Val Loss: 0.37897989153862
# SNR: -5/-5, LS_CNN, Epoch 17/50, Loss: 0.3860473881165187
# SNR: -5/-5, LS_CNN, Val Loss: 0.37601153552532196
# SNR: -5/-5, LS_CNN, Epoch 18/50, Loss: 0.38420700033505756
# SNR: -5/-5, LS_CNN, Val Loss: 0.37489947158357373
# SNR: -5/-5, LS_CNN, Epoch 19/50, Loss: 0.38224079873826766
# SNR: -5/-5, LS_CNN, Val Loss: 0.37335929857647937
# SNR: -5/-5, LS_CNN, Epoch 20/50, Loss: 0.379795307914416
# SNR: -5/-5, LS_CNN, Val Loss: 0.37291577069655707
# SNR: -5/-5, LS_CNN, Epoch 21/50, Loss: 0.37658188740412396
# SNR: -5/-5, LS_CNN, Val Loss: 0.36583897924941516
# SNR: -5/-5, LS_CNN, Epoch 22/50, Loss: 0.37387190924750435
# SNR: -5/-5, LS_CNN, Val Loss: 0.36301399832186493
# SNR: -5/-5, LS_CNN, Epoch 23/50, Loss: 0.37246954772207475
# SNR: -5/-5, LS_CNN, Val Loss: 0.36088531885458075
# SNR: -5/-5, LS_CNN, Epoch 24/50, Loss: 0.3711080782943302
# SNR: -5/-5, LS_CNN, Val Loss: 0.3604543617238169
# SNR: -5/-5, LS_CNN, Epoch 25/50, Loss: 0.36683303283320534
# SNR: -5/-5, LS_CNN, Val Loss: 0.35830884783164313
# SNR: -5/-5, LS_CNN, Epoch 26/50, Loss: 0.36366745995150673
# SNR: -5/-5, LS_CNN, Val Loss: 0.3532172026841537
# SNR: -5/-5, LS_CNN, Epoch 27/50, Loss: 0.36180569065941703
# SNR: -5/-5, LS_CNN, Val Loss: 0.35103216896886413
# SNR: -5/-5, LS_CNN, Epoch 28/50, Loss: 0.3584266122844484
# SNR: -5/-5, LS_CNN, Val Loss: 0.34564545167529065
# SNR: -5/-5, LS_CNN, Epoch 29/50, Loss: 0.3567123015721639
# SNR: -5/-5, LS_CNN, Val Loss: 0.3421357831229334
# SNR: -5/-5, LS_CNN, Epoch 30/50, Loss: 0.3539103865623474
# SNR: -5/-5, LS_CNN, Val Loss: 0.3422961740390114
# SNR: -5/-5, LS_CNN, Epoch 31/50, Loss: 0.3506120973163181
# SNR: -5/-5, LS_CNN, Val Loss: 0.33847942559615424
# SNR: -5/-5, LS_CNN, Epoch 32/50, Loss: 0.3479468822479248
# SNR: -5/-5, LS_CNN, Val Loss: 0.3373707202465638
# SNR: -5/-5, LS_CNN, Epoch 33/50, Loss: 0.3447190870841344
# SNR: -5/-5, LS_CNN, Val Loss: 0.3334501307943593
# SNR: -5/-5, LS_CNN, Epoch 34/50, Loss: 0.34454525344901615
# SNR: -5/-5, LS_CNN, Val Loss: 0.3312433938617292
# SNR: -5/-5, LS_CNN, Epoch 35/50, Loss: 0.3411317351791594
# SNR: -5/-5, LS_CNN, Val Loss: 0.32286227915598
# SNR: -5/-5, LS_CNN, Epoch 36/50, Loss: 0.33672934936152565
# SNR: -5/-5, LS_CNN, Val Loss: 0.3205663548863452
# SNR: -5/-5, LS_CNN, Epoch 37/50, Loss: 0.33368007010883755
# SNR: -5/-5, LS_CNN, Val Loss: 0.32114246098891547
# SNR: -5/-5, LS_CNN, Epoch 38/50, Loss: 0.33229438794983757
# SNR: -5/-5, LS_CNN, Val Loss: 0.3175326793090157
# SNR: -5/-5, LS_CNN, Epoch 39/50, Loss: 0.3266529424322976
# SNR: -5/-5, LS_CNN, Val Loss: 0.31181442737579346
# SNR: -5/-5, LS_CNN, Epoch 40/50, Loss: 0.32616009480423397
# SNR: -5/-5, LS_CNN, Val Loss: 0.30692837290141894
# SNR: -5/-5, LS_CNN, Epoch 41/50, Loss: 0.3204907344447242
# SNR: -5/-5, LS_CNN, Val Loss: 0.30492584990418475
# SNR: -5/-5, LS_CNN, Epoch 42/50, Loss: 0.3172215421994527
# SNR: -5/-5, LS_CNN, Val Loss: 0.30381594792656275
# SNR: -5/-5, LS_CNN, Epoch 43/50, Loss: 0.3130960116783778
# SNR: -5/-5, LS_CNN, Val Loss: 0.2977710845677749
# SNR: -5/-5, LS_CNN, Epoch 44/50, Loss: 0.30968482626809013
# SNR: -5/-5, LS_CNN, Val Loss: 0.29575969537963037
# SNR: -5/-5, LS_CNN, Epoch 45/50, Loss: 0.30622319380442303
# SNR: -5/-5, LS_CNN, Val Loss: 0.28961340597142343
# SNR: -5/-5, LS_CNN, Epoch 46/50, Loss: 0.3052835332022773
# SNR: -5/-5, LS_CNN, Val Loss: 0.28888789953097055
# SNR: -5/-5, LS_CNN, Epoch 47/50, Loss: 0.30700694024562836
# SNR: -5/-5, LS_CNN, Val Loss: 0.2858975121508474
# SNR: -5/-5, LS_CNN, Epoch 48/50, Loss: 0.2988490064938863
# SNR: -5/-5, LS_CNN, Val Loss: 0.284704501538173
# SNR: -5/-5, LS_CNN, Epoch 49/50, Loss: 0.29651276187764275
# SNR: -5/-5, LS_CNN, Val Loss: 0.2782585374687029
# SNR: -5/-5, LS_CNN, Epoch 50/50, Loss: 0.2954610172245238
# SNR: -5/-5, LS_CNN, Val Loss: 0.2758812700276789
# LS+CNN NMSE: 0.06244073435664177
# LS+LI NMSE: 0.2599731683731079
# LS_LI_CNN model
# SNR: -5/-5, LS_LI_CNN, Epoch 1/50, Loss: 0.41632380253738827
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.4066438888726027
# SNR: -5/-5, LS_LI_CNN, Epoch 2/50, Loss: 0.41056686143080395
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.4007363086161406
# SNR: -5/-5, LS_LI_CNN, Epoch 3/50, Loss: 0.4050981667306688
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3949906605741252
# SNR: -5/-5, LS_LI_CNN, Epoch 4/50, Loss: 0.399554000960456
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3892487663289775
# SNR: -5/-5, LS_LI_CNN, Epoch 5/50, Loss: 0.39397020637989044
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3830897665542105
# SNR: -5/-5, LS_LI_CNN, Epoch 6/50, Loss: 0.38811569743686253
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.37729125437529193
# SNR: -5/-5, LS_LI_CNN, Epoch 7/50, Loss: 0.38224944803449845
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.370783938013989
# SNR: -5/-5, LS_LI_CNN, Epoch 8/50, Loss: 0.37577899131509995
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.36436048862726794
# SNR: -5/-5, LS_LI_CNN, Epoch 9/50, Loss: 0.3701527863740921
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3570994663497676
# SNR: -5/-5, LS_LI_CNN, Epoch 10/50, Loss: 0.3631906923320558
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3504603809636572
# SNR: -5/-5, LS_LI_CNN, Epoch 11/50, Loss: 0.35735759304629433
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3449889097524726
# SNR: -5/-5, LS_LI_CNN, Epoch 12/50, Loss: 0.3510482327805625
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.33846754224404046
# SNR: -5/-5, LS_LI_CNN, Epoch 13/50, Loss: 0.34465494089656407
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.33212162619051727
# SNR: -5/-5, LS_LI_CNN, Epoch 14/50, Loss: 0.3395463128884633
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.32539026050463965
# SNR: -5/-5, LS_LI_CNN, Epoch 15/50, Loss: 0.3345165153344472
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3217050484989
# SNR: -5/-5, LS_LI_CNN, Epoch 16/50, Loss: 0.329877366622289
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3179792279134626
# SNR: -5/-5, LS_LI_CNN, Epoch 17/50, Loss: 0.32611510819858974
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.31254769894091977
# SNR: -5/-5, LS_LI_CNN, Epoch 18/50, Loss: 0.32273585100968677
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.31023963735155435
# SNR: -5/-5, LS_LI_CNN, Epoch 19/50, Loss: 0.31990619997183484
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.30866766850585525
# SNR: -5/-5, LS_LI_CNN, Epoch 20/50, Loss: 0.31656170388062793
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3075556010007858
# SNR: -5/-5, LS_LI_CNN, Epoch 21/50, Loss: 0.31507137252224815
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3046134849605353
# SNR: -5/-5, LS_LI_CNN, Epoch 22/50, Loss: 0.3124437944756614
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.300895396458066
# SNR: -5/-5, LS_LI_CNN, Epoch 23/50, Loss: 0.3118818882438872
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.3004917482966962
# SNR: -5/-5, LS_LI_CNN, Epoch 24/50, Loss: 0.3102051466703415
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2985570320616598
# SNR: -5/-5, LS_LI_CNN, Epoch 25/50, Loss: 0.30882977114783394
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2956345444140227
# SNR: -5/-5, LS_LI_CNN, Epoch 26/50, Loss: 0.3097302168607712
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2954939027195391
# SNR: -5/-5, LS_LI_CNN, Epoch 27/50, Loss: 0.3087880114714305
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29666896941869153
# SNR: -5/-5, LS_LI_CNN, Epoch 28/50, Loss: 0.3073257389995787
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2962729898483857
# SNR: -5/-5, LS_LI_CNN, Epoch 29/50, Loss: 0.30480796098709106
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2960400267139725
# SNR: -5/-5, LS_LI_CNN, Epoch 30/50, Loss: 0.3081049107842975
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2944433183773704
# SNR: -5/-5, LS_LI_CNN, Epoch 31/50, Loss: 0.3065503281023767
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2945230240407197
# SNR: -5/-5, LS_LI_CNN, Epoch 32/50, Loss: 0.3050975882344776
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2955700567235117
# SNR: -5/-5, LS_LI_CNN, Epoch 33/50, Loss: 0.30541079077455735
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29306424538726394
# SNR: -5/-5, LS_LI_CNN, Epoch 34/50, Loss: 0.30424972209665513
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2943294848436895
# SNR: -5/-5, LS_LI_CNN, Epoch 35/50, Loss: 0.30497204181220794
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29383727875740634
# SNR: -5/-5, LS_LI_CNN, Epoch 36/50, Loss: 0.30415463116433883
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29318907727365906
# SNR: -5/-5, LS_LI_CNN, Epoch 37/50, Loss: 0.3054190120763249
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29455986683783325
# SNR: -5/-5, LS_LI_CNN, Epoch 38/50, Loss: 0.30377525670660865
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2930318288829016
# SNR: -5/-5, LS_LI_CNN, Epoch 39/50, Loss: 0.30350564751360154
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2925468453246614
# SNR: -5/-5, LS_LI_CNN, Epoch 40/50, Loss: 0.3040252708726459
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29110886188952817
# SNR: -5/-5, LS_LI_CNN, Epoch 41/50, Loss: 0.30211617714828914
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2922831164753955
# SNR: -5/-5, LS_LI_CNN, Epoch 42/50, Loss: 0.3028551861643791
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29248315743778064
# SNR: -5/-5, LS_LI_CNN, Epoch 43/50, Loss: 0.3021907102730539
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29193938879863074
# SNR: -5/-5, LS_LI_CNN, Epoch 44/50, Loss: 0.3024759085641967
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29116283648687863
# SNR: -5/-5, LS_LI_CNN, Epoch 45/50, Loss: 0.3018765383296543
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2918667242578838
# SNR: -5/-5, LS_LI_CNN, Epoch 46/50, Loss: 0.30268104208840263
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2912030531012494
# SNR: -5/-5, LS_LI_CNN, Epoch 47/50, Loss: 0.3023606398039394
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29281307270993356
# SNR: -5/-5, LS_LI_CNN, Epoch 48/50, Loss: 0.3020184553331799
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2900656393688658
# SNR: -5/-5, LS_LI_CNN, Epoch 49/50, Loss: 0.30027742352750564
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.2891379747053851
# SNR: -5/-5, LS_LI_CNN, Epoch 50/50, Loss: 0.30221837262312573
# SNR: -5/-5, LS_LI_CNN, Val Loss: 0.29153130333060806
# LS+CNN NMSE: 0.06169966980814934

# %%
from torchsummary import summary
summary(model_source, input_size=(1,612,14))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#        BatchNorm2d-1           [-1, 1, 612, 14]               2
#             Conv2d-2          [-1, 64, 612, 14]           5,248
#               Tanh-3          [-1, 64, 612, 14]               0
#             Conv2d-4          [-1, 64, 612, 14]         102,464
#               Tanh-5          [-1, 64, 612, 14]               0
#            Dropout-6          [-1, 64, 612, 14]               0
#             Conv2d-7          [-1, 64, 612, 14]         102,464
#               Tanh-8          [-1, 64, 612, 14]               0
#             Conv2d-9          [-1, 32, 612, 14]          51,232
#              Tanh-10          [-1, 32, 612, 14]               0
#           Dropout-11          [-1, 32, 612, 14]               0
#            Conv2d-12           [-1, 1, 612, 14]             801
# ================================================================
# Total params: 262,211
# Trainable params: 803
# Non-trainable params: 261,408
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 35.69
# Params size (MB): 1.00
# Estimated Total Size (MB): 36.72
# ----------------------------------------------------------------

# %%
summary(model_fineTune, input_size=(1,612,14))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#        BatchNorm2d-1           [-1, 1, 612, 14]               2
#             Conv2d-2          [-1, 64, 612, 14]           5,248
#               Tanh-3          [-1, 64, 612, 14]               0
#             Conv2d-4          [-1, 64, 612, 14]         102,464
#               Tanh-5          [-1, 64, 612, 14]               0
#            Dropout-6          [-1, 64, 612, 14]               0
#             Conv2d-7          [-1, 64, 612, 14]         102,464
#               Tanh-8          [-1, 64, 612, 14]               0
#             Conv2d-9          [-1, 32, 612, 14]          51,232
#              Tanh-10          [-1, 32, 612, 14]               0
#           Dropout-11          [-1, 32, 612, 14]               0
#            Conv2d-12          [-1, 16, 616, 18]          12,816
#              Tanh-13          [-1, 16, 616, 18]               0
#            Conv2d-14           [-1, 8, 614, 16]           1,160
#              Tanh-15           [-1, 8, 614, 16]               0
#            Conv2d-16           [-1, 1, 612, 14]              73
# ================================================================
# Total params: 275,459
# Trainable params: 14,051
# Non-trainable params: 261,408
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 39.60
# Params size (MB): 1.05
# Estimated Total Size (MB): 40.68
# ----------------------------------------------------------------

# %%
plt.figure(figsize=(10, 5))
plt.plot(SNR, nmse_LS_LI_val, label='LS+LI')
plt.plot(SNR, nmse_LS_NN_val, label='LS+CNN')
plt.plot(SNR, nmse_LI_NN_val, label='LS+LI+CNN')
plt.xlabel('SNR (dB)')
plt.ylabel('NMSE')
plt.title('Average NMSE over SNR')
plt.legend()
plt.savefig(os.path.join(transferd_save_path, "NMSE1.png")) # transferd_save_path = f"transferd_model/static/CNN/ver{idx_save_path}_"
plt.show()
print('Figure saved at ')
print(os.path.join(transferd_save_path, "NMSE1.png"))

savemat(os.path.join(transferd_save_path, 'NMSE.mat'), {'nmse_LS_LI_val': nmse_LS_LI_val, 'nmse_LS_NN_val':nmse_LS_NN_val, 'nmse_LI_NN_val':nmse_LI_NN_val})
# Out:
# Figure saved at
# transferd_model/static/CNN/ver11_/NMSE1.png

# %%
plt.figure(figsize=(10, 5))
plt.plot(SNR, nmse_LS_NN_val, label='LS+CNN')
plt.plot(SNR, nmse_LI_NN_val, label='LS+LI+CNN')
plt.xlabel('SNR (dB)')
plt.ylabel('NMSE')
plt.title('Average NMSE over SNR')
plt.legend()
plt.show()

# %%
nmse_LI_NN_val
# Out:
# [tensor(0.1071),
#  tensor(0.1083),
#  tensor(0.1039),
#  tensor(0.0783),
#  tensor(0.0617)]
